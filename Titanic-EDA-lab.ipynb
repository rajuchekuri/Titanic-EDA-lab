# %%
import pandas as pd

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df=pd.read_csv("train.csv")

# %% [markdown]
# 1.Is the variable categorical or continuous.
# <li>ans:<li> In titanic data set we have both categorical and continuos variables.
#     <li>categorical variables are - ' Sex, Survived, pclass, Embarked '
#     <li>continuos variables are - ' Age, Fare, Ticket, PassengerId and cabin '

# %% [markdown]
# 2.Are there missing values?
# <li>ans: <li>There are missing values for
#          <li>Age and cabin
#          <li>There are "177" missing values in Age variable and "687" missing values in Cabin variable

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %% [markdown]
# 3.Min, Max, Mean and Standard Deviation of the continuos variables

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# 4.Histograms describing the distribution of the variables
#  <li>I have done it for Fare and Age

# %%
import matplotlib as plt

# %%
df.Fare.hist(bins=10)
plt.pyplot.xlabel('Fare')
plt.pyplot.ylabel('Count of Passengers')

# %%
df.Age.hist(bins=10)
plt.pyplot.xlabel('Age')
plt.pyplot.ylabel('Count of Passengers')

# %% [markdown]
# ###5. EDA for all the variables

# %% [markdown]
# 1.PassengerId
#
#  <li>Is Continuous variable
#  <li>And there are no missing values in PassengerId

# %%
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# 2.Survived
#
#   <li>Is Categorical variable and ther are two categories in this
#   <li>1 for Survived
#   <li>0 for Dead
#
#   <li>And there are no missing values.

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# dtype: int64

# %%
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# 3.Pclass
#
#   <li>Is categorical variable
#   <li>There are 3 categories in it
#   <li>1st class
#   <li>2nd class
#   <li>3rd class
#   <li>And there are no missing values in Pclass variable.

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# dtype: int64

# %%
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Pclass.value_counts().plot(kind='bar')

# %% [markdown]
# 4.Sex
#
#   <li>Sex is categorical variable
#   <li>And it has 2 categories in it
#    <li>Male
#    <li>Female
#   <li>There are no missing values in Sex variable

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# dtype: int64

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Sex.value_counts().plot(kind='bar')

# %% [markdown]
# 5.Age
#
#   <li>Age is Continuous variable
#   <li>With minimum value = 0.42,   maximum value = 80,    avg = 29.69
#   <li>There are "177" missing values in Age variable.

# %%
df.Age.min()
# Out:
# 0.42

# %%
df.Age.max()
# Out:
# 80.0

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df.Age.hist()

# %% [markdown]
# 6.SibSP
#
#   <li>It's a categorical variable, since it has 7 categories in it.
#   <li>And there is no missing values in SibSp

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# dtype: int64

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.SibSp.value_counts().plot(kind='bar')

# %% [markdown]
# 7.Parch
#
#  <li>This is Parent/children aboard count and is Categorical Variable
#  <li>And there are 7 categories in the Parch
#  <li>No missing values in this variable

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# dtype: int64

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Parch.value_counts().plot(kind='bar')

# %% [markdown]
# 8.Ticket
#
#   <li>This is Continuous variable
#   <li>Since it's a ticket number there is no minimum, maximum and average values
#   <li>There are no Missing values

# %%
df.Ticket.value_counts()
# Out:
# CA. 2343             7
# 347082               7
# 1601                 7
# 347088               6
# CA 2144              6
# 3101295              6
# 382652               5
# S.O.C. 14879         5
# PC 17757             4
# 4133                 4
# LINE                 4
# 349909               4
# 347077               4
# W./C. 6608           4
# 113760               4
# 2666                 4
# 113781               4
# 19950                4
# 17421                4
# 347742               3
# 239853               3
# 110152               3
# 24160                3
# 13502                3
# PC 17572             3
# C.A. 34651           3
# 248727               3
# 35273                3
# F.C.C. 13529         3
# PC 17755             3
#                     ..
# 330877               1
# 315094               1
# 236852               1
# 4137                 1
# 4136                 1
# 226593               1
# 4134                 1
# 374746               1
# 110813               1
# ...

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# 9.Fare
#
#   <li>Fare is continuous variable
#   <li>Minimum value = 0 ,   Maximum value = 512.32 ,   Average = 32.20
#   <li>And there is no missing values in Fare

# %%
df.Fare.value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
# 10.5000    24
# 7.9250     18
# 7.7750     16
# 7.2292     15
# 26.5500    15
# 0.0000     15
# 7.2500     13
# 7.8542     13
# 8.6625     13
# 7.2250     12
# 16.1000     9
# 9.5000      9
# 15.5000     8
# 24.1500     8
# 14.4542     7
# 14.5000     7
# 56.4958     7
# 69.5500     7
# 52.0000     7
# 31.2750     7
# 7.0500      7
# 27.9000     6
# 21.0000     6
# 26.2500     6
# 30.0000     6
#            ..
# 5.0000      1
# 71.2833     1
# 9.4833      1
# 59.4000     1
# 25.5875     1
# 15.0458     1
# 7.7875      1
# 8.4042      1
# 12.0000     1
# 12.2750     1
# 42.4000     1
# 8.1375      1
# 14.0000     1
# 21.6792     1
# 12.5250     1
# 15.0000     1
# 28.7125     1
# 61.1750     1
# 6.2375      1
# 15.1000     1
# 39.4000     1
# 81.8583     1
# 61.9792     1
# 7.8000      1
# 22.0250     1
# 47.1000     1
# 13.4167     1
# 14.1083     1
# 15.5500     1
# 13.7917     1
# dtype: int64

# %%
df.Fare.min()
# Out:
# 0.0

# %%
df.Fare.max()
# Out:
# 512.3292

# %%
df.Fare.mean()
# Out:
# 32.2042079685746

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Fare.hist(bins=10)

# %% [markdown]
# 10.Cabin
#
#   <li>Cabin is Continuous variable
#   <li>There is min, max and mean in the cabin since the values are alpha-numeric
#   <li>There are 481 Missing values in the cabin variable

# %%
df.Cabin.value_counts()
# Out:
# C23 C25 C27        4
# G6                 4
# B96 B98            4
# D                  3
# C22 C26            3
# E101               3
# F2                 3
# F33                3
# B57 B59 B63 B66    2
# C68                2
# B58 B60            2
# E121               2
# D20                2
# E8                 2
# E44                2
# B77                2
# C65                2
# D26                2
# E24                2
# E25                2
# B20                2
# C93                2
# D33                2
# E67                2
# D35                2
# D36                2
# C52                2
# F4                 2
# C125               2
# C124               2
#                   ..
# F G63              1
# A6                 1
# D45                1
# D6                 1
# D56                1
# C101               1
# C54                1
# D28                1
# D37                1
# B102               1
# D30                1
# E17                1
# ...

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %% [markdown]
# 11.Embarked
#
#    <li>This is Categorical variable
#    <li>There are three Categories C=cherbourg, Q=queenstown and S=southampton
#    <li>And 2 missing values in Embarked variable

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# dtype: int64

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex  Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female   38      0      0  113572    80   B28      NaN
# 829  female   62      0      0  113572    80   B28      NaN

# %%
df.Embarked.value_counts().plot(kind='barh')

# %% [markdown]
# Please let me know if I have to add few more things to my work
# And would like to send some more things that I've done
